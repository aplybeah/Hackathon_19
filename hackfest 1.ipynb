# %%
# Import libaries
import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup
from time import sleep 
from selenium import webdriver

# %%
url = 'https://www.fbo.gov/index.php?s=opportunity&mode=list&tab=list&pageID=1'

result = requests.get(url)   #putting the html into a variable called results 
result
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(result.content, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
# <head>
# <meta content="IE=8" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>Opportunities - Federal Business Opportunities: Opportunities</title>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="https://static.symplicity.com/yui/build/autocomplete/assets/skins/sam/autocomplete.css?t=1382626706&amp;css=autocomplete" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://static.symplicity.com/yui/build/container/assets/skins/sam/container.css?t=1309361679&amp;css=container" media="all" rel="stylesheet" type="text/css"/>
# <style media="all" type="text/css">
# select { max-width: 100%; }
#
# .yui-skin-sam .yui-ac-container {
#   left:0px !important;
#   width:100%px !important;
#   height:auto;
# }
# .yui-skin-sam .yui-ac-input {
# ...

# %%
# homepage= soup.find('', {'class': 'lst-cl lst-cl-first'}).find('table')

results_page = soup.find('table', {'class': 'list'})

# %%
results_page
# Out:
# <table class="list" summary="List of matching items 1 - 20 of 31500">
# <tr>
# <th class="lst-hd lst-hd-first" id="lh_id" scope="col">Opportunity</th>
# <th class="lst-hd" id="lh_full_agency_s" scope="col"><a href="?_psort=full_agency_s-d-asc">Agency/Office/Location <img alt="Sort" border="0" src="/images/list_sort_descending.gif" title="Sort"/></a></th>
# <th class="lst-hd" id="lh_base_type" scope="col"><a href="?_psort=base_type-d-asc">Type <img alt="Sort" border="0" src="/images/list_sort_descending.gif" title="Sort"/></a>/  <a href="?_psort=current_set_aside_s-d-asc">Set-aside <img alt="Sort" border="0" src="/images/list_sort_descending.gif" title="Sort"/></a></th>
# <th class="lst-hd lst-hd-last first_sort" id="lh_current_posted_date" scope="col"><a href="?_psort=current_posted_date-d-asc">Posted On <img alt="Sort" border="0" src="/images/list_sort_ascending.gif" title="Sort"/></a></th>
# </tr>
# <tr class="lst-rw lst-rw-first lst-rw-odd" id="row_0">
# ...

# %%
page = soup.find_all('a', {'href': '?s=opportunity&mode=form&id=9451b835518af4d8585114ba5617db40&tab=core&_cview=0'})
